# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
##an alternative to plt.show() ie the immediate line above 
import numpy as np

x = np.arange(6)
y = np.arange(6)
print("x", x)
print("y", y)

plt.plot(x, y)
# Out:
# x [0 1 2 3 4 5]
# y [0 1 2 3 4 5]

# %%
plt.plot(x, y, "xg")

# %%
data = np.array([1, 2, 1, 2, 5, 1 ,2])
plt.title("My title")
plt.xlabel("x label")
plt.ylabel("y label")
plt.plot(data)

# %%
plt.title("My title")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis([1, 4, -2, 7])
plt.plot(data)

# %%
plt.hist(data)
# Out:
# (array([3., 0., 3., 0., 0., 0., 0., 0., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)
